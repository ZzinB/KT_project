# %%
# 필요한 라이브러리 설치 및 임포트
# !pip install pandas

import pandas as pd
import datetime

# %% [markdown]
# ---

# %% [markdown]
# # [Step 2] 데이터 전처리

# %% [markdown]
# #### **<span style="color:blue">[2-0] air_21, air_22, weather_21, weather_22 데이터 로딩</span>**

# %%
# 데이터 로딩
air_21 = pd.read_csv('air_2021.csv', sep=',', encoding='utf-8', index_col=0)
air_22 = pd.read_csv('air_2022.csv', sep=',', encoding='utf-8', index_col=0)
weather_21 = pd.read_csv("weather_2021.csv", sep = ',', encoding='cp949')
weather_22 = pd.read_csv("weather_2022.csv", sep = ',', encoding='cp949')

# %%
air_21.head()
# Out:
#        지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0  서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1  서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2  서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3  서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4  서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
#
#    PM25                주소
# 0  18.0  서울 종로구 종로35가길 19
# 1  16.0  서울 종로구 종로35가길 19
# 2  18.0  서울 종로구 종로35가길 19
# 3  16.0  서울 종로구 종로35가길 19
# 4  16.0  서울 종로구 종로35가길 19

# %% [markdown]
# #### **<span style="color:blue">[2-1] air_21, air_22 의 '측정일시'를 활용하여 'time' 변수 생성</span>**

# %% [markdown]
# * air_21, air_22 의 '측정일시'를 활용하여 'time'변수 생성
# * time 변수를 to_datetime으로 데이터 타입 변경
# * 참고: 미세먼지 데이터는 1시-24시, 날씨 데이터는 0시-23시로 구성되어 있습니다. [2-5]에서 미세먼지와 날씨 데이터를 time 기준으로 합치려면 날씨 기준이 동일해야 합니다. 미세먼지 데이터에서 time 변수 생성 시 이를 미리 고려(예:측정일시 값 -1)하세요.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
air_21['time'], air_22['time'] = air_21['측정일시'] - 1, air_22['측정일시'] - 1
air_21['time'] = pd.to_datetime(air_21['time'], format='%Y%m%d%H')
air_22['time'] = pd.to_datetime(air_22['time'], format='%Y%m%d%H')

# %%
air_21.head()
# Out:
#        지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0  서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1  서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2  서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3  서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4  서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
#
#    PM25                주소                time
# 0  18.0  서울 종로구 종로35가길 19 2021-10-01 00:00:00
# 1  16.0  서울 종로구 종로35가길 19 2021-10-01 01:00:00
# 2  18.0  서울 종로구 종로35가길 19 2021-10-01 02:00:00
# 3  16.0  서울 종로구 종로35가길 19 2021-10-01 03:00:00
# 4  16.0  서울 종로구 종로35가길 19 2021-10-01 04:00:00

# %%
air_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2160 entries, 0 to 2159
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      2160 non-null   object
#  1   망       2160 non-null   object
#  2   측정소코드   2160 non-null   int64
#  3   측정소명    2160 non-null   object
#  4   측정일시    2160 non-null   int64
#  5   SO2     2139 non-null   float64
#  6   CO      2139 non-null   float64
#  7   O3      2139 non-null   float64
#  8   NO2     2139 non-null   float64
#  9   PM10    2122 non-null   float64
#  10  PM25    2135 non-null   float64
#  11  주소      2160 non-null   object
#  12  time    2160 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(2), object(4)
# memory usage: 236.2+ KB

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-2] weather_21, weather_22 의 '일시'를 활용하여 'time' 변수 생성</span>**

# %% [markdown]
# * weather_21, weather_22 의 '일시'를 활용하여 'time'변수 생성
# * time 변수를 to_datetime으로 데이터 타입 변경

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
weather_21['time'], weather_22['time'] = weather_21['일시'], weather_22['일시']
weather_21['time'] = pd.to_datetime(weather_21['time'])
weather_22['time'] = pd.to_datetime(weather_22['time'])

# %%
weather_21.head()
# Out:
#     지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  108  서울  2021-01-01 01:00    -8.7       NaN      NaN        NaN      2.4
# 1  108  서울  2021-01-01 02:00    -9.1       NaN      NaN        NaN      1.6
# 2  108  서울  2021-01-01 03:00    -9.3       NaN      NaN        NaN      1.1
# 3  108  서울  2021-01-01 04:00    -9.3       NaN      NaN        NaN      0.3
# 4  108  서울  2021-01-01 05:00    -9.7       NaN      NaN        NaN      1.9
#
#    풍속 QC플래그  풍향(16방위)  풍향 QC플래그  습도(%)  습도 QC플래그  증기압(hPa)  이슬점온도(°C)  \
# 0       NaN     270.0       NaN     68       NaN       2.2      -13.5
# 1       NaN     270.0       NaN     69       NaN       2.1      -13.7
# 2       NaN     250.0       NaN     70       NaN       2.1      -13.7
# 3       NaN       0.0       NaN     71       NaN       2.2      -13.5
# 4       NaN      20.0       NaN     72       NaN       2.1      -13.8
#
#    현지기압(hPa)  현지기압 QC플래그  해면기압(hPa)  해면기압 QC플래그  일조(hr)  일조 QC플래그  일사(MJ/m2)  \
# ...

# %%
air_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2160 entries, 0 to 2159
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      2160 non-null   object
#  1   망       2160 non-null   object
#  2   측정소코드   2160 non-null   int64
#  3   측정소명    2160 non-null   object
#  4   측정일시    2160 non-null   int64
#  5   SO2     2139 non-null   float64
#  6   CO      2139 non-null   float64
#  7   O3      2139 non-null   float64
#  8   NO2     2139 non-null   float64
#  9   PM10    2122 non-null   float64
#  10  PM25    2135 non-null   float64
#  11  주소      2160 non-null   object
#  12  time    2160 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(2), object(4)
# memory usage: 236.2+ KB

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-3] 'time' 기준으로 데이터 합치기</span>**

# %% [markdown]
# * 미세먼지 데이터와 날씨 데이터를 'time' 기준으로 합쳐보세요.
# * df_21에는 'time' 기준으로 21년도 미세먼지, 날씨 데이터를 합쳐보세요.
# * df_22에는 'time' 기준으로 22년도 미세먼지, 날씨 데이터를 합쳐보세요.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
df_21 = pd.merge(air_21, weather_21, on='time')
df_22 = pd.merge(air_22, weather_22, on='time')

# %%
df_21

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8759 entries, 2021-10-01 00:00:00 to 2021-09-30 23:00:00
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SO2            8759 non-null   float64
#  1   CO             8759 non-null   float64
#  2   O3             8759 non-null   float64
#  3   NO2            8759 non-null   float64
#  4   PM10           8759 non-null   float64
#  5   PM25           8759 non-null   float64
#  6   기온(°C)         8759 non-null   float64
#  7   강수량(mm)        8759 non-null   float64
#  8   풍속(m/s)        8759 non-null   float64
#  9   풍향(16방위)       8759 non-null   float64
#  10  습도(%)          8759 non-null   int64
#  11  증기압(hPa)       8759 non-null   float64
#  12  현지기압(hPa)      8759 non-null   float64
#  13  해면기압(hPa)      8759 non-null   float64
#  14  일조(hr)         8759 non-null   float64
#  15  일사(MJ/m2)      8759 non-null   float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-4] 사용하지 않을 변수 제거</span>**

# %% [markdown]
# * 머신러닝에 사용하지 않을 변수들을 제거해줍니다.
# * df_21, df_22에 사용할 변수들만 넣어보세요.

# %%
df_211 = df_21.loc[:, [ 'CO', 'NO2', '기온(°C)','일사(MJ/m2)', '습도(%)', '강수량(mm)', '풍속(m/s)']]
df_222 = df_22.loc[:, [ 'CO', 'NO2', '기온(°C)','일사(MJ/m2)', '습도(%)', '강수량(mm)', '풍속(m/s)']]

# %%
# df_21, df_22에 사용할 변수들만 할당
drop_cols = ['지면상태(지면상태코드)','현상번호(국내식)', '최저운고(100m )', '망', '측정소명', '측정소코드', '주소', '주소', '지점', '지점명', '이슬점온도(°C)', '적설(cm)', '3시간신적설(cm)', '운형(운형약어)', '최저운고(100m )', '일시', '측정일시']
df_21.drop(drop_cols, axis=1, inplace=True)
df_22.drop(drop_cols, axis=1, inplace=True)

# %%
drop_cols = ['기온 QC플래그', '강수량 QC플래그', '풍속 QC플래그', '풍향 QC플래그', '습도 QC플래그', '현지기압 QC플래그', '해면기압 QC플래그', '일사 QC플래그', '일조 QC플래그', '지면온도 QC플래그']
df_21.drop(drop_cols, axis=1, inplace=True)
df_22.drop(drop_cols, axis=1, inplace=True)

# %%
drop_cols = ['지역']
df_21.drop(drop_cols, axis=1, inplace=True)
df_22.drop(drop_cols, axis=1, inplace=True)

# %%
df_21.head()

# %%
# time 변수를 index로 세팅
df_21 = df_21.set_index("time")
df_22 = df_22.set_index("time")

# %%
df_21.head()
# Out:
#                          지역    SO2   CO     O3    NO2  PM10  PM25  기온(°C)  \
# time
# 2021-10-01 00:00:00  서울 종로구  0.003  0.6  0.002  0.039  31.0  18.0    19.2
# 2021-10-01 01:00:00  서울 종로구  0.003  0.6  0.002  0.035  27.0  16.0    18.7
# 2021-10-01 02:00:00  서울 종로구  0.003  0.6  0.002  0.033  28.0  18.0    18.3
# 2021-10-01 03:00:00  서울 종로구  0.003  0.6  0.002  0.030  26.0  16.0    17.7
# 2021-10-01 04:00:00  서울 종로구  0.003  0.5  0.003  0.026  26.0  16.0    17.4
#
#                      기온 QC플래그  강수량(mm)  ...  일사 QC플래그  전운량(10분위)  중하층운량(10분위)  \
# time                                    ...
# 2021-10-01 00:00:00       NaN      NaN  ...       9.0        0.0            0
# 2021-10-01 01:00:00       NaN      NaN  ...       9.0        0.0            0
# 2021-10-01 02:00:00       NaN      NaN  ...       9.0        0.0            0
# 2021-10-01 03:00:00       NaN      NaN  ...       9.0        0.0            0
# 2021-10-01 04:00:00       NaN      NaN  ...       9.0        0.0            0
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-5] 변수들의 결측치 처리</span>**

# %%
# df_21, df_22의 결측치 확인
df_21.isna().sum()
# Out:
# 지역                  0
# SO2               112
# CO                 80
# O3                 97
# NO2                80
# PM10              105
# PM25               97
# time                0
# 기온(°C)              0
# 강수량(mm)             0
# 풍속(m/s)             2
# 풍향(16방위)            2
# 습도(%)               0
# 증기압(hPa)            0
# 현지기압(hPa)           0
# 해면기압(hPa)           0
# 일조(hr)           3968
# 일사(MJ/m2)        3968
# 전운량(10분위)           2
# 중하층운량(10분위)         0
# 시정(10m)             0
# 지면온도(°C)            5
# 5cm 지중온도(°C)        5
# 10cm 지중온도(°C)       5
# 20cm 지중온도(°C)       5
# 30cm 지중온도(°C)       5
# dtype: int64

# %%
df_21['강수량(mm)'].value_counts(dropna=True)
# Out:
# 0.0     436
# 0.1      55
# 0.2      47
# 0.3      45
# 0.5      23
# 0.7      23
# 0.8      19
# 0.4      19
# 0.6      18
# 1.3      17
# 1.0      16
# 1.2      14
# 1.5      12
# 1.8       9
# 1.1       9
# 0.9       8
# 2.2       8
# 2.0       7
# 2.4       5
# 3.5       5
# 3.1       5
# 1.4       5
# 1.7       5
# 3.7       5
# 2.5       4
# 4.0       4
# 4.5       4
# 4.4       4
# 1.6       4
# 2.6       4
# 4.8       4
# 4.3       4
# 2.7       4
# 2.1       4
# 1.9       4
# 3.6       4
# 3.3       3
# 3.0       3
# 8.0       3
# 4.7       3
# 5.9       3
# 2.3       3
# 10.6      2
# 5.8       2
# 2.9       2
# 8.1       2
# 5.7       2
# 10.0      2
# 4.6       2
# 5.1       2
# 6.8       2
# 4.1       2
# 2.8       2
# 6.0       2
# 3.4       2
# 13.6      1
# 6.4       1
# 10.8      1
# 64.7      1
# 11.5      1
# 7.0       1
# 12.8      1
# 12.5      1
# 22.4      1
# 30.2      1
# 9.3       1
# 8.9       1
# 11.6      1
# 7.1       1
# 3.8       1
# 7.8       1
# ...

# %%
df_21['강수량(mm)'].fillna('0', inplace=True)
df_22['강수량(mm)'].fillna('0', inplace=True)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_21.head(300)
# Out:
#          지역    SO2   CO     O3    NO2  PM10  PM25                time  기온(°C)  \
# 0    서울 종로구  0.003  0.6  0.002  0.039  31.0  18.0 2021-10-01 00:00:00    19.2
# 1    서울 종로구  0.003  0.6  0.002  0.035  27.0  16.0 2021-10-01 01:00:00    18.7
# 2    서울 종로구  0.003  0.6  0.002  0.033  28.0  18.0 2021-10-01 02:00:00    18.3
# 3    서울 종로구  0.003  0.6  0.002  0.030  26.0  16.0 2021-10-01 03:00:00    17.7
# 4    서울 종로구  0.003  0.5  0.003  0.026  26.0  16.0 2021-10-01 04:00:00    17.4
# 5    서울 종로구  0.003  0.5  0.002  0.025  22.0  14.0 2021-10-01 05:00:00    17.2
# 6    서울 종로구  0.003  0.5  0.002  0.024  25.0  14.0 2021-10-01 06:00:00    17.0
# 7    서울 종로구  0.003  0.5  0.005  0.023  24.0  14.0 2021-10-01 07:00:00    17.0
# 8    서울 종로구  0.003  0.5  0.011  0.020  23.0  12.0 2021-10-01 08:00:00    17.5
# 9    서울 종로구  0.003  0.6  0.026  0.016  40.0  22.0 2021-10-01 09:00:00    19.8
# 10   서울 종로구  0.003  0.5  0.031  0.014  49.0  29.0 2021-10-01 10:00:00    21.4
# ...

# %%
# df_21, df_22의 변수 중 '강수량(mm)'의 결측치를 처리

# %%
df_21['지면온도(°C)'].fillna(method='ffill', inplace=True)
df_21['5cm 지중온도(°C)'].fillna(method='ffill', inplace=True)
df_21['10cm 지중온도(°C)'].fillna(method='ffill', inplace=True)
df_21['20cm 지중온도(°C)'].fillna(method='ffill', inplace=True)
df_21['30cm 지중온도(°C)'].fillna(method='ffill', inplace=True)
df_21['전운량(10분위)'].fillna(method='ffill', inplace=True)
df_21['풍속(m/s)'].fillna(method='ffill', inplace=True)
df_21['풍향(16방위)'].fillna(method='ffill', inplace=True)
df_22['지면온도(°C)'].fillna(method='ffill', inplace=True)
df_22['5cm 지중온도(°C)'].fillna(method='ffill', inplace=True)
df_22['10cm 지중온도(°C)'].fillna(method='ffill', inplace=True)
df_22['20cm 지중온도(°C)'].fillna(method='ffill', inplace=True)
df_22['30cm 지중온도(°C)'].fillna(method='ffill', inplace=True)
df_22['전운량(10분위)'].fillna(method='ffill', inplace=True)
df_22['풍속(m/s)'].fillna(method='ffill', inplace=True)
df_22['풍향(16방위)'].fillna(method='ffill', inplace=True)

# %%
mean_hr = df_21['일조(hr)'].mean()
mean = df_21['일사(MJ/m2)'].mean()
df_21['일조(hr)'].fillna(mean_hr, inplace=True)
df_21['일사(MJ/m2)'].fillna(mean, inplace=True)
mean_hr2 = df_22['일조(hr)'].mean()
mean2 = df_22['일사(MJ/m2)'].mean()
df_22['일조(hr)'].fillna(mean_hr2, inplace=True)
df_22['일사(MJ/m2)'].fillna(mean2, inplace=True)

# %%
# df_21, df_22의 남은 결측치를 처리
df_22.isna().sum()
# Out:
# SO2              2160
# CO               2160
# O3               2160
# NO2              2160
# PM10             2160
# PM25             2160
# 기온(°C)              0
# 강수량(mm)          2079
# 풍속(m/s)             0
# 풍향(16방위)            0
# 습도(%)               0
# 증기압(hPa)            0
# 현지기압(hPa)           0
# 해면기압(hPa)           0
# 일조(hr)              0
# 일사(MJ/m2)           0
# 전운량(10분위)           0
# 중하층운량(10분위)         0
# 시정(10m)             0
# 지면온도(°C)            0
# 5cm 지중온도(°C)        0
# 10cm 지중온도(°C)       0
# 20cm 지중온도(°C)       0
# 30cm 지중온도(°C)       0
# PM10_lag1        2160
# PM10_1           2160
# dtype: int64

# %%
df_21['PM25'].value_counts(dropna=True)
# Out:
# 12.0     381
# 13.0     370
# 15.0     359
# 16.0     350
# 14.0     349
# 11.0     346
# 10.0     341
# 17.0     319
# 9.0      313
# 8.0      305
# 18.0     286
# 7.0      276
# 19.0     262
# 23.0     242
# 20.0     234
# 5.0      233
# 21.0     232
# 6.0      216
# 24.0     212
# 22.0     210
# 4.0      182
# 26.0     177
# 25.0     174
# 28.0     168
# 27.0     159
# 3.0      146
# 29.0     119
# 2.0      109
# 30.0     106
# 1.0      102
# 31.0      93
# 34.0      83
# 33.0      82
# 32.0      69
# 38.0      60
# 35.0      54
# 36.0      51
# 44.0      47
# 37.0      47
# 40.0      45
# 39.0      44
# 41.0      41
# 42.0      40
# 43.0      30
# 45.0      25
# 50.0      24
# 47.0      24
# 48.0      24
# 51.0      21
# 49.0      21
# 59.0      20
# 46.0      20
# 52.0      18
# 54.0      17
# 53.0      16
# 57.0      16
# 58.0      15
# 64.0      15
# 55.0      14
# 56.0      13
# 60.0      12
# 73.0      12
# 62.0      12
# 68.0      11
# 69.0      11
# 67.0      11
# ...

# %%
df_21['SO2'].fillna('0.003', inplace=True)
df_21['CO'].fillna('0.4', inplace=True)
df_21['O3'].fillna('0.002', inplace=True)
df_21['NO2'].fillna('0.012', inplace=True)
df_21['O3'].fillna('0.002', inplace=True)
df_21['PM10'].fillna('20.0', inplace=True)
df_21['PM25'].fillna('12.0', inplace=True)

# %%
df_22['SO2'].fillna('0.003', inplace=True)
df_22['CO'].fillna('0.4', inplace=True)
df_22['O3'].fillna('0.002', inplace=True)
df_22['NO2'].fillna('0.012', inplace=True)
df_22['O3'].fillna('0.002', inplace=True)
df_22['PM10'].fillna('20.0', inplace=True)
df_22['PM25'].fillna('12.0', inplace=True)

# %%
# df_21, df_22의 결측치 재확인
df_22.isna().sum()
# Out:
# SO2                 0
# CO                  0
# O3                  0
# NO2                 0
# PM10                0
# PM25                0
# 기온(°C)              0
# 강수량(mm)             0
# 풍속(m/s)             0
# 풍향(16방위)            0
# 습도(%)               0
# 증기압(hPa)            0
# 현지기압(hPa)           0
# 해면기압(hPa)           0
# 일조(hr)              0
# 일사(MJ/m2)           0
# 전운량(10분위)           0
# 중하층운량(10분위)         0
# 시정(10m)             0
# 지면온도(°C)            0
# 5cm 지중온도(°C)        0
# 10cm 지중온도(°C)       0
# 20cm 지중온도(°C)       0
# 30cm 지중온도(°C)       0
# PM10_lag1        2160
# PM10_1           2160
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-6] 전일 같은 시간 변수 추가</span>**

# %% [markdown]
# * 모델링에 유용한 변수로 전일 같은 시간(24시간 전) 미세먼지 농도 변수를 추가합니다.
# * 시계열 데이터 처리를 위한 shift 연산을 참고하세요.

# %%
# df_21, df_22의 index(time)를 month, day, hour 로 쪼개기 (year는 필요 없음)
df_21['month'] = df_21.index.month

# %%
df_21['month'] = df_21.index.month
df_21['day'] = df_21.index.day
df_21['hour'] = df_21.index.time

# %%
df_21.head(2)
# Out:
#                          지역    SO2   CO     O3    NO2  PM10  PM25  기온(°C)  \
# time
# 2021-10-01 00:00:00  서울 종로구  0.003  0.6  0.002  0.039  31.0  18.0    19.2
# 2021-10-01 01:00:00  서울 종로구  0.003  0.6  0.002  0.035  27.0  16.0    18.7
#
#                     강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  증기압(hPa)  현지기압(hPa)  \
# time
# 2021-10-01 00:00:00       0      1.3     360.0     83      18.4      998.8
# 2021-10-01 01:00:00       0      1.0      20.0     85      18.3      998.8
#
#                      해면기압(hPa)   일조(hr)  일사(MJ/m2)  전운량(10분위)  중하층운량(10분위)  \
# time
# 2021-10-01 00:00:00     1008.7  0.45838   1.076706        0.0            0
# 2021-10-01 01:00:00     1008.7  0.45838   1.076706        0.0            0
#
#                      시정(10m)  지면온도(°C)  5cm 지중온도(°C)  10cm 지중온도(°C)  \
# time
# 2021-10-01 00:00:00     2000      17.8          22.3           22.3
# 2021-10-01 01:00:00     2000      17.4          22.1           22.0
#
# ...

# %%
# df_21, df_22에 전일 같은 시간 미세먼지 농도 변수(PM10_lag1) 추가
# 전일 같은 시간은 24시간 전 입니다.
df_21['PM10_lag1'] = df_21['PM10'].shift(24)

# %%
df_22['PM10_lag1'] = df_22['PM10'].shift(24)

# %%
df_21.head(30)
# Out:
#                          지역    SO2   CO     O3    NO2  PM10  PM25  기온(°C)  \
# time
# 2021-10-01 00:00:00  서울 종로구  0.003  0.6  0.002  0.039  31.0  18.0    19.2
# 2021-10-01 01:00:00  서울 종로구  0.003  0.6  0.002  0.035  27.0  16.0    18.7
# 2021-10-01 02:00:00  서울 종로구  0.003  0.6  0.002  0.033  28.0  18.0    18.3
# 2021-10-01 03:00:00  서울 종로구  0.003  0.6  0.002   0.03  26.0  16.0    17.7
# 2021-10-01 04:00:00  서울 종로구  0.003  0.5  0.003  0.026  26.0  16.0    17.4
# 2021-10-01 05:00:00  서울 종로구  0.003  0.5  0.002  0.025  22.0  14.0    17.2
# 2021-10-01 06:00:00  서울 종로구  0.003  0.5  0.002  0.024  25.0  14.0    17.0
# 2021-10-01 07:00:00  서울 종로구  0.003  0.5  0.005  0.023  24.0  14.0    17.0
# 2021-10-01 08:00:00  서울 종로구  0.003  0.5  0.011   0.02  23.0  12.0    17.5
# 2021-10-01 09:00:00  서울 종로구  0.003  0.6  0.026  0.016  40.0  22.0    19.8
# 2021-10-01 10:00:00  서울 종로구  0.003  0.5  0.031  0.014  49.0  29.0    21.4
# 2021-10-01 11:00:00  서울 종로구  0.003  0.5  0.035  0.017  43.0  24.0    23.0
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-7] t+1 시점의 미세먼지 농도 데이터 생성</span>**

# %% [markdown]
# * t+1 시점은 1시간 후 입니다.
# * t+1 시점의 미세먼지 농도 변수를 생성하세요.
# * t+1 시점의 미세먼지 농도는 머신러닝 모델을 통해 예측하려는 y값(target) 입니다.

# %%
# df_21, df_22에 t+1 시점 변수(PM10_1) 추가
df_21['PM10_1'] = df_21['PM10'].shift(-1)

# %%
df_22['PM10_1'] = df_22['PM10'].shift(-1)

# %%
df_21.tail(30)
# Out:
#                        SO2   CO     O3    NO2  PM10  PM25  기온(°C) 강수량(mm)  \
# time
# 2021-09-29 18:00:00  0.003  0.4  0.016  0.017  11.0   8.0    20.2     0.1
# 2021-09-29 19:00:00  0.003  0.5  0.014  0.018  15.0   9.0    19.8       0
# 2021-09-29 20:00:00  0.003  0.5  0.006  0.024  18.0  13.0    19.6       0
# 2021-09-29 21:00:00  0.003  0.7  0.005  0.025  15.0   9.0    19.3       0
# 2021-09-29 22:00:00  0.003  0.5  0.007  0.021  14.0   8.0    18.8       0
# 2021-09-29 23:00:00  0.003  0.5  0.004  0.021  11.0   6.0    18.3       0
# 2021-09-30 00:00:00  0.003  0.4  0.004  0.019  13.0   6.0    17.8       0
# 2021-09-30 01:00:00  0.003  0.4  0.005  0.018  13.0   7.0    17.5       0
# 2021-09-30 02:00:00  0.003  0.4  0.006  0.015  14.0  11.0    17.2       0
# 2021-09-30 03:00:00  0.003  0.4  0.006  0.013  15.0  10.0    17.0       0
# 2021-09-30 04:00:00  0.003  0.4  0.008  0.013  14.0   9.0    16.8       0
# 2021-09-30 05:00:00  0.002  0.4  0.007  0.014  11.0   7.0    16.4       0
# ...

# %%
df_22.tail(70)
# Out:
#                        SO2   CO     O3    NO2  PM10  PM25  기온(°C)  강수량(mm)  \
# time
# 2022-03-29 02:00:00  0.002  0.5  0.013  0.035  28.0  16.0     4.5      0.0
# 2022-03-29 03:00:00  0.003  0.6  0.004  0.046  30.0  15.0     4.3      0.0
# 2022-03-29 04:00:00  0.003  0.6  0.002  0.047  37.0  18.0     3.8      0.0
# 2022-03-29 05:00:00  0.002  0.6  0.002  0.048  38.0  18.0     3.5      0.0
# 2022-03-29 06:00:00  0.003  0.6  0.003  0.049  37.0  19.0     3.3      0.0
# 2022-03-29 07:00:00  0.004  0.6  0.005  0.047  39.0  19.0     3.5      0.0
# 2022-03-29 08:00:00  0.004  0.7  0.009  0.050  50.0  24.0     5.1      0.0
# 2022-03-29 09:00:00  0.004  0.6  0.017  0.046  54.0  26.0     8.0      0.0
# 2022-03-29 10:00:00  0.004  0.4  0.036  0.028  46.0  23.0    10.8      0.0
# 2022-03-29 11:00:00  0.004  0.4  0.048  0.016  33.0  13.0    12.5      0.0
# 2022-03-29 12:00:00  0.004  0.4  0.051  0.017  33.0  14.0    13.9      0.0
# ...

# %%
# 결측치가 있다면 처리
df_21.isna().sum()
# Out:
# SO2               0
# CO                0
# O3                0
# NO2               0
# PM10              0
# PM25              0
# 기온(°C)            0
# 강수량(mm)           0
# 풍속(m/s)           0
# 풍향(16방위)          0
# 습도(%)             0
# 증기압(hPa)          0
# 현지기압(hPa)         0
# 해면기압(hPa)         0
# 일조(hr)            0
# 일사(MJ/m2)         0
# 전운량(10분위)         0
# 중하층운량(10분위)       0
# 시정(10m)           0
# 지면온도(°C)          0
# 5cm 지중온도(°C)      0
# 10cm 지중온도(°C)     0
# 20cm 지중온도(°C)     0
# 30cm 지중온도(°C)     0
# PM10_lag1        24
# PM10_1            1
# dtype: int64

# %%
df_21['PM10'].value_counts(dropna=True)
# Out:
# 20.0     250
# 19.0     227
# 16.0     218
# 24.0     213
# 21.0     208
# 18.0     199
# 17.0     198
# 14.0     184
# 23.0     183
# 31.0     180
# 22.0     180
# 36.0     176
# 25.0     175
# 27.0     161
# 28.0     161
# 15.0     160
# 26.0     159
# 29.0     157
# 34.0     157
# 30.0     157
# 32.0     157
# 13.0     153
# 33.0     153
# 12.0     150
# 9.0      150
# 37.0     148
# 38.0     144
# 35.0     142
# 11.0     141
# 10.0     139
# 40.0     133
# 39.0     128
# 8.0      117
# 43.0     115
# 7.0      109
# 3.0      109
# 41.0     106
# 20.0     105
# 44.0      97
# 42.0      94
# 46.0      94
# 49.0      85
# 51.0      85
# 48.0      80
# 45.0      79
# 55.0      73
# 6.0       71
# 52.0      71
# 5.0       70
# 50.0      68
# 56.0      62
# 47.0      60
# 53.0      60
# 54.0      59
# 4.0       57
# 60.0      52
# 59.0      44
# 62.0      44
# 58.0      43
# 66.0      42
# 57.0      37
# 65.0      36
# 61.0      36
# 77.0      35
# 70.0      35
# 64.0      32
# ...

# %%
df_21['PM10_lag1'].fillna(20, inplace=True)
df_22['PM10_lag1'].fillna(20, inplace=True)
df_21['PM10_1'].fillna(method='ffill', inplace=True)
df_22['PM10_1'].fillna(method='ffill', inplace=True)

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8759 entries, 2021-10-01 00:00:00 to 2021-09-30 23:00:00
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SO2            8759 non-null   float64
#  1   CO             8759 non-null   float64
#  2   O3             8759 non-null   float64
#  3   NO2            8759 non-null   float64
#  4   PM10           8759 non-null   float64
#  5   PM25           8759 non-null   float64
#  6   기온(°C)         8759 non-null   float64
#  7   강수량(mm)        8759 non-null   object
#  8   풍속(m/s)        8759 non-null   float64
#  9   풍향(16방위)       8759 non-null   float64
#  10  습도(%)          8759 non-null   int64
#  11  증기압(hPa)       8759 non-null   float64
#  12  현지기압(hPa)      8759 non-null   float64
#  13  해면기압(hPa)      8759 non-null   float64
#  14  일조(hr)         8759 non-null   float64
#  15  일사(MJ/m2)      8759 non-null   float64
# ...

# %%
df_21['강수량(mm)'] = df_21['강수량(mm)'].astype('float') 
df_21['SO2'] = df_21['SO2'].astype('float') 
df_21['CO'] = df_21['CO'].astype('float') 
df_21['O3'] = df_21['O3'].astype('float') 
df_21['NO2'] = df_21['NO2'].astype('float') 
df_21['PM10'] = df_21['PM10'].astype('float') 
df_21['PM25'] = df_21['PM25'].astype('float') 
df_21['PM10_lag1'] = df_21['PM10_lag1'].astype('float') 
df_21['PM10_1'] = df_21['PM10_1'].astype('float') 
df_22['SO2'] = df_22['SO2'].astype('float') 
df_22['CO'] = df_22['CO'].astype('float') 
df_22['O3'] = df_22['O3'].astype('float') 
df_22['NO2'] = df_22['NO2'].astype('float') 
df_22['PM10'] = df_22['PM10'].astype('float') 
df_22['PM25'] = df_22['PM25'].astype('float') 
df_22['PM10_lag1'] = df_22['PM10_lag1'].astype('float') 
df_22['PM10_1'] = df_22['PM10_1'].astype('float') 
df_22['강수량(mm)'] = df_22['강수량(mm)'].astype('float')

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8759 entries, 2021-10-01 00:00:00 to 2021-09-30 23:00:00
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SO2            8759 non-null   float64
#  1   CO             8759 non-null   float64
#  2   O3             8759 non-null   float64
#  3   NO2            8759 non-null   float64
#  4   PM10           8759 non-null   float64
#  5   PM25           8759 non-null   float64
#  6   기온(°C)         8759 non-null   float64
#  7   강수량(mm)        8759 non-null   float64
#  8   풍속(m/s)        8759 non-null   float64
#  9   풍향(16방위)       8759 non-null   float64
#  10  습도(%)          8759 non-null   int64
#  11  증기압(hPa)       8759 non-null   float64
#  12  현지기압(hPa)      8759 non-null   float64
#  13  해면기압(hPa)      8759 non-null   float64
#  14  일조(hr)         8759 non-null   float64
#  15  일사(MJ/m2)      8759 non-null   float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-8] train, test 데이터 분리</span>**

# %% [markdown]
# * 21년도 데이터(df_21)를 train 데이터로 저장하세요. y 값을 제외하고 train_x로 저장한 후 y 값은 train_y로 저장하세요.
# * 22년도 데이터(df_22)를 test 데이터로 저장하세요. y 값을 제외하고 test_x로 저장한 후 y 값은 test_y로 저장하세요.
# * 각각의 데이터프레임을 csv 파일로 저장하세요. (train_x.csv / train_y.csv / test_x.csv / test_y.csv)
# * y값은 'PM10_1' 즉, t+1 시점의 미세먼지 농도입니다.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
target = 'PM10_1'
train_x = df_21.drop(target, axis=1)
train_y = df_21.loc[:, target]
test_x = df_22.drop(target, axis=1)
test_y = df_22.loc[:, target]

train_x1 = df_211.drop(target, axis=1)
train_y1 = df_211.loc[:, target]
test_x1 = df_222.drop(target, axis=1)
test_y1 = df_222.loc[:, target]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[326], line 8
#       5 test_x = df_22.drop(target, axis=1)
#       6 test_y = df_22.loc[:, target]
# ----> 8 train_x1 = df_211.drop(target, axis=1)
#       9 train_y1 = df_211.loc[:, target]
#      10 test_x1 = df_222.drop(target, axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
# 각각의 데이터프레임을 csv 파일로 저장 (train_x.csv / train_y.csv / test_x.csv / test_y.csv)
train_x.to_csv("train_x.csv", index = False)
train_y.to_csv("train_y.csv", index = False)
test_x.to_csv("test_x.csv", index = False)
test_y.to_csv("test_y.csv", index = False)
